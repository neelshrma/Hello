# %%
x=5+1j
type(x)

# %%
x=6
y=5.5
z=9.8+6j
print("Type of x=",type(x),sep='\t')
print("Type of x=",type(y))
print("Type of x=",type(z))
# Out:
# Type of x=	<class 'int'>
# Type of x= <class 'float'>
# Type of x= <class 'complex'>

# %%
x=input("enter a value:")
print("type of x=",type(x))
# Out:
# enter a value:45
# type of x= <class 'str'>

# %%
x=input("enter a value:")
#print("type of x=",type(x))
print("type of x=",type(x))
y=input("enter a value:")
#print("type of y=",type(y))
print("type of y=",type(y))
print("Addition of ",x,'+',y,'=',x+y)
# Out:
# enter a value:4
# type of x= <class 'str'>
# enter a value:5
# type of y= <class 'str'>
# Addition of  4 + 5 = 45

# %% [markdown]
# ######

# %%
x=input("enter a value:")
print("type of x=",type(x))
y=input("enter a value:")
print("type of y=",type(y))
print(eval(x+y))
# Out:
# enter a value:4
# type of x= <class 'str'>
# enter a value:5
# type of y= <class 'str'>
# 45

# %%
d={
    'one':{
        'two':(['hello',1,2,{'dog':'bitch'}],"animals",[2,3.4])
    }
}
print(d)
# Out:
# {'one': {'two': (['hello', 1, 2, {'dog': 'bitch'}], 'animals', [2, 3.4])}}

# %%
d['one']
# Out:
# {'two': (['hello', 1, 2, {'dog': 'bitch'}], 'animals', [2, 3.4])}

# %%
d['one']['two'][2]
# Out:
# [2, 3.4]

# %%
d
# Out:
# {'one': {'two': (['hello', 1, 2, {'dog': 'bitch'}], 'animals', [2, 3.4])}}

# %%
x='hello'
print(format(x,'*',[20])

# %%
x= 7
y=8
z=x>y
print(z)
# Out:
# False

# %%
x= int(input("enter value of x:"))
y= int(input("enter value of y:"))
z=x>y
z
# Out:
# enter value of x:6
# enter value of y:9
# False

# %%
x=int(input("enter value:")) < int(input("enter value :"))
x
# Out:
# enter value:6
# enter value :5
# False

# %%
5.6 >4.5
# Out:
# True

# %%
5.6==5.4
# Out:
# False

# %%
s1="nilofar"
s2="sourabh"
s1>s2
# Out:
# False

# %%
s2>s1
# Out:
# True

# %%
s1=input("enter name:")
s2=input("enter another name:")
if len(s1) > len(s2) :
print(s1,"is bigger than",s2)
else :
print(s1,"shorter than",s2)
print(len(s1))
print(len(s2))
# Out:
#   File "<ipython-input-1-ac19cedea24f>", line 4
#     print(s1,"is bigger than",s2)
#         ^
# IndentationError: expected an indented block

# %%
s1=input("enter name:")
s2=input("enter another name:")
if len(s1) > len(s2) :
  print (s1,"is bigger than",s2)
else :
  print (s1,"shorter than",s2)
# Out:
# enter name:neel
# enter another name:sourabh
# neel shorter than sourabh

# %%
s1=input("enter name:")
s2=input("enter another name:")
if s1 > s2 :
    
   print(s1,"is bigger than",s2)

else :
   print(s1,"shorter than",s2)
# Out:
# enter name:neeel
# enter another name:mov
# neeel is bigger than mov

# %%
n1= input("enter name:")
if n1:
    print("welcome to the world my dear {}.format(n1)")
   
else:
        print("sorryyy")
# Out:
# enter name:neel
# welcome to the world my dear {}.format(n1)

# %%
info={'n1':[]}

n1= input("enter name:")
info['n1'].append(n1)
if n1:
    print("welcome to the world my dear {}".format(n1))
   
else:
     print("sorryyy")
# Out:
# enter name:mov
# welcome to the world my dear mov

# %%
info
# Out:
# {'n1': ['mov']}

# %%
'' or 0
# Out:
# 0

# %%
'' or 1
# Out:
# 1

# %%
'' and 1
# Out:
# ''

# %%
'hi' or 'zoo'
# Out:
# 'hi'

# %%
'hi' or []
# Out:
# 'hi'

# %%
'hi' and []
# Out:
# []

# %%
() or []
# Out:
# []

# %%
print("hello world")
print('hello world')
# Out:
# hello world
# hello world

# %%
#"hello world"
'hello world'
# Out:
# 'hello world'

# %%
3+(2*4)
# Out:
# 11

# %%
_*3
# Out:
# 33

# %%
_*4
# Out:
# 132

# %%
''*4
# Out:
# ''

# %%
[]*3
# Out:
# []

# %%
[[]]*3
# Out:
# [[], [], []]

# %%
x=[1,2,3,'hello',56]
z=['','','','']
y=dict(zip(x,z))
print(y)
# Out:
# {1: '', 2: '', 3: '', 'hello': ''}

# %%
7 and 8
# Out:
# 8

# %%
8 and 7
# Out:
# 7

# %%
not ''
# Out:
# True

# %%
{} and [] or ()
# Out:
# ()

# %%
1 or 4 or 6
# Out:
# 1

# %%
1>5<6
# Out:
# False

# %%
7>3<5
# Out:
# True

# %%
'' or '*'
# Out:
# '*'

# %%
# Bitwise operator

x=61
y=27

# %%
bin(x)
# Out:
# '0b111101'

# %%
bin(y)
# Out:
# '0b11011'

# %%
~0
# Out:
# -1

# %%
print("negation of {} is {}.". format(y,~y))
# Out:
# negation of 27 is -28.

# %%
print("bitwise and of {} and {} is {}.".format(x,y,x&y))
# Out:
# bitwise and of 61 and 27 is 25.

# %%
print("bitwise or of {} and {} is {}.".format(x,y,x|y))
# Out:
# bitwise or of 61 and 27 is 63.

# %%
print("Bitwise >>(right shift) of {} >> {} is {}". format(x,y,x>>y))
# Out:
# Bitwise >>(right shift) of 61 >> 27 is 0

# %%
print("Bitwise ^(xor) of {} ^ {} is {}". format(x,y,x^y))
# Out:
# Bitwise ^(xor) of 61 ^ 27 is 38

# %%
56>>2
# Out:
# 14

# %%
27>>3
# Out:
# 3

# %%
61>>3
# Out:
# 7

# %%
#Assignment operator

# %%
10%3
# Out:
# 1

# %%
10/3
# Out:
# 3.3333333333333335

# %%
1//3
# Out:
# 0

# %%
10//3
# Out:
# 3

# %%
import operator
x=10
y=3
print(operator.mod(10,3))
print(operator.add(10,3))
print(operator.sub(10,3))
print(operator.pow(10,3))
print(operator.truediv(10,3))
# Out:
# 1
# 13
# 7
# 1000
# 3.3333333333333335

# %%
[1,2,3] and [5,6,7]
# Out:
# [5, 6, 7]

# %%
x=1234
y=1234
x or y
print(id(x))
print(id(y))
# Out:
# 87529968
# 87530768

# %%
#condition statement - if else
# : indentation operator

# %%
x=6
y=7
z=8
if (x>y) and (x>z):
   print ("x is greater.")
elif(y>x) and (y>z):                #in python if we have to use many conditions, then we use elif
   print ("y is greater.")
else :
   print("z is greater.")
# Out:
# z is greater.

# %%
x=5
y=6
z=7
print(x)
print(y)
print(z)
# Out:
# 5
# 6
# 7

# %%
x=5
y=6
z=7
if (x>y) :
    if (y>z): #nested if else
       print("x is greater",x)
    else :
       print("z is greater",z)
elif y>z :
        print("y is greater")
else:
    print("z is greater")
# Out:
# z is greater

# %%
# if user input foo than print bar inop, or if user gives 
#inpout as bar than print foo in o/p, else print use foo|bar

# %%
user1 = input("value1:")
user2= input("value2 :")
if ('user1'=='foo'):
   print("bar")
elif('user2'=='bar'):
   print("foo")
else :
   print("foo|bar")

# %%
user1 = input("value1:").strip().lower()
#user2= input("value2:")  # user=''.join(user.split())
if user1=='foo':
   print("bar")
elif user1 =='bar':
   print("foo")
else :
   print("foo|bar")
# Out:
# value1:neel/
# foo|bar

# %%
x= input("name :").upper()
x=''.join(x.split())
print(x)
# Out:
# name :s   o   u   r   a   b   h
# SOURABH

# %%
x={'1':'one','2':'two','3':'three'}
y=list(x)

#print(list(x))
print(y)
# Out:
# ['1', '2', '3']

# %%
y
# Out:
# ['1', '2', '3']

# %%
s = sum(y)
s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-d05db101a32f> in <module>()
# ----> 1 s = sum(y)
#       2 s
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
s
# Out:
# 6

# %%
x= input("salary:")
if x>='80000' and x>='200000' :
    print("you are approved")
else :
    print("you are not approved.")
# Out:
# salary:70000
# you are not approved.

# %%
n =input("enter:")
if(n/5) :
    print("Y")
else :
    print("N")
# Out:
# enter:10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-778c86ad6b62> in <module>()
#       1 n =input("enter:")
# ----> 2 if(n/5) :
#       3     print("Y")
#       4 else :
#       5     print("N")
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
bin()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-c411d4a4f3e2> in <module>()
# ----> 1 bin()
#
# TypeError: bin() takes exactly one argument (0 given)

# %%
x = int(input("enter number:"))
if x%5 == 0 and x%11 == 0 :
    print("x is divisible by 5 and 11.")
else :
    print("its not divisible.")
# Out:
# enter number:55
# x is divisible by 5 and 11.

# %%
#Leap year

year =int(input("enter a year :"))
if year%4==0 :
    if year%100==0 :
        if year%400==0 :
            print("leap year")
        else :
            print("not leap year")
    else :
        print("leap year")
else :
    print("this is not leap year")
# Out:
# enter a year :2100
# not leap year

# %%
year = int(input("enter year :"))
if (year%4==0) and (year %100 or year %400==0) :
    print("leap year")
else :
    print("not leap year")
# Out:
# enter year :1900
# not leap year

# %%
#isalpha() - only alphabets
x= input("enter any alphabet")
if x.isalpha():
    print("string is correct")
else :
    print("not alphabets")
# Out:
# enter any alphabety
# string is correct

# %%
s= "helloworld"
print(dir(s))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
if print("[]") :
    print("easy")
else :
    print("tough")
# Out:
# []
# tough

# %%
s= "hello"
print(s.istitle ())
print(s.isalnum())
print(s.isalpha())
# Out:
# False
# True
# True

# %%
#to check vowel and consonent
x=input("enter any character:").lower()
if (x=='a'or x=='A' or x=='e'or x=='E' or x=='i' or x=='I' or x=='o' or x=='O' or x=='u' or x=='U'):
    print("{} is vowel.".format(x))
else :
    print("not vowel")
# Out:
# enter any character:A
# a is vowel.

# %%
import
week = {0:'Sunday',1:'Monday',2:'Tuesday',3:'wednesday',4:'Thursday',5:'Friday',6:'Saturday',7:'Sunday'}
data = week.get(week)
if data :
    print("week day :")
else :
    print("nothing")
# Out:
#   File "<ipython-input-34-5bbf0f800f9c>", line 1
#     import from week
#               ^
# SyntaxError: invalid syntax

# %%
#count total no. of notes
x = input("enter amount:")

# %%
week = {0:'Sunday',1:'Monday',2:'Tuesday',3:'wednesday',4:'Thursday',5:'Friday',6:'Saturday',7:'Sunday'}
print(dir(week))
# Out:
# ['__class__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']

# %%
import 
week = {0:'Sunday',1:'Monday',2:'Tuesday',3:'wednesday',4:'Thursday',5:'Friday',6:'Saturday',7:'Sunday'}
data = week.get(data)
if data:
    print("week day")
else :
    print("nothing")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-6f1ac6835293> in <module>()
# ----> 1 import data
#       2 week = {0:'Sunday',1:'Monday',2:'Tuesday',3:'wednesday',4:'Thursday',5:'Friday',6:'Saturday',7:'Sunday'}
#       3 data = week.get(data)
#       4 if data:
#       5     print("week day")
#
# ModuleNotFoundError: No module named 'data'

# %%
x = '123769'
r = int(x,base=8)
print(r)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-bfa15393f3dc> in <module>()
#       1 x = '123769'
# ----> 2 r = int(x,base=8)
#       3 print(r)
#
# ValueError: invalid literal for int() with base 8: '123769'

# %%
from random import randint
randint(1,50)   # will generate random no.
num = ("enter number :")
while num<='50' :
    if num==13 :
        print ("you are winner")
    else :
        print("you have lost")

# %%
a=int(input("Enter the first number:"))
b=int(input("Enter the second number:"))
if(a>b):
    min=a
else:
    min=b
while(1):
    if(min%a==0 and min%b==0):
        print("LCM is:",min)
        break
    min=min+1
# Out:
# Enter the first number:6
# Enter the second number:4
# LCM is: 12

# %%
import math
print(dir(math))
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'ceil', 'copysign', 'cos', 'cosh', 'degrees', 'e', 'erf', 'erfc', 'exp', 'expm1', 'fabs', 'factorial', 'floor', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'pi', 'pow', 'radians', 'sin', 'sinh', 'sqrt', 'tan', 'tanh', 'tau', 'trunc']

# %%
import factorial
x =  5
help(factorial)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-719037b7edc4> in <module>()
# ----> 1 import factorial
#       2 x =  5
#       3 help(factorial)
#
# ModuleNotFoundError: No module named 'factorial'

# %%
x= input("enter value :")
while x.factorial() :
    print("value of {} :".format(x))
# Out:
# enter value :4
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-9fcb2d0db00f> in <module>()
#       1 x= input("enter value :")
# ----> 2 while x.factorial() :
#       3     print("value of {} :".format(x))
#
# AttributeError: 'str' object has no attribute 'factorial'

# %%
import math
factorial = int(input("enter :"))
help(factorial)
# Out:
# enter :4
# Help on int object:
#
# class int(object)
#  |  int(x=0) -> integer
#  |  int(x, base=10) -> integer
#  |
#  |  Convert a number or string to an integer, or return 0 if no arguments
#  |  are given.  If x is a number, return x.__int__().  For floating point
#  |  numbers, this truncates towards zero.
#  |
#  |  If x is not a number or if base is given, then x must be a string,
#  |  bytes, or bytearray instance representing an integer literal in the
#  |  given base.  The literal can be preceded by '+' or '-' and be surrounded
#  |  by whitespace.  The base defaults to 10.  Valid bases are 0 and 2-36.
#  |  Base 0 means to interpret the base from the string as an integer literal.
#  |  >>> int('0b100', base=0)
#  |  4
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __and__(self, value, /)
#  |      Return self&value.
#  |
#  |  __bool__(self, /)
#  |      self != 0
# ...

# %%
from math import factorial
x= int(input("enter value :"))

while factorial(x) :
    print("value :",x)
# Out:
# enter value :4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# value : 4
# ...

# %%
x= int(input("enter value :"))
copy_x = x
factorial=1
while x >0 :
    factorial = factorial*x
    x=x-1
    print("factorial of {} is {}:".format(copy_x,factorial))
# Out:
# enter value :-4

# %%
row = 0
while row <= 10 : 
    column = 0
    while column <= row :
        print("*",sep='')
        column += 1
    print()
    row += 1
# Out:
# *
#
# *
# *
#
# *
# *
# *
#
# *
# *
# *
# *
#
# *
# *
# *
# *
# *
#
# *
# *
# *
# *
# *
# *
#
# *
# *
# *
# *
# *
# *
# *
#
# *
# *
# *
# *
# *
# *
# *
# *
#
# *
# *
# *
# *
# *
# *
# *
# *
# *
#
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
#
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *

# %%
num = input("Enter a number : ") # you know input is a string
if num == num[::-1] :
    print("no.{} is pelindrome".format(num))
else :
    print()
# Out:
# Enter a number : 2222

# %%
num = int(input("Enter a number : "))
copy = num #for later use to check 
rev_num = 0
while num : 
    last_digit = num % 10  #taking out the last digit
    rev_num = rev_num * 10 + last_digit #making new number
    num = num // 10 #update number
if rev_num == copy : 
    print("Given number {} is Palindrome number.".format(copy))
else : 
    print("Given number {} is not Palindrome number.".format(copy))
# Out:
# Enter a number : 121
# Given number 121 is Palindrome number.
