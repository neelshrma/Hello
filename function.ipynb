# %%
#Function is a gp. of statements to perform specific tasks.
# built -in  &   user-defined

# %%
import this              # introduction of python
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
def greeting() :
    print("welcome to python")

# %%
greeting()
# Out:
# welcome to python

# %%
x= greeting()
print(x)
# Out:
# welcome to python
# None

# %%
def greeting() :
    print("welcome to python")
    return 'enjoy'

# %%
greeting()
# Out:
# welcome to python
# 'enjoy'

# %%
x= greeting()
print(x)
# Out:
# welcome to python
# enjoy

# %%
def greeting() :
    return 'enjoy'
    print("welcome to python")
x=greeting()    
print(x)
# Out:
# enjoy

# %%
def hello(name):
    print("welcome {} to the world".format(name))
    return 0
if hello(name):
    print("serious")
else :
    print("genious")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-d58ede7ab121> in <module>()
#       2     print("welcome {} to the world".format(name))
#       3     return 0
# ----> 4 if hello(name):
#       5     print("serious")
#       6 else :
#
# NameError: name 'name' is not defined

# %%
def hello(name):
    print("welcome {} to the world".format(name))
    return 0    # 0 - false
if hello('neel'):
    print("serious")
else :
    print("genious")
# Out:
# welcome neel to the world
# genious

# %%
def even(var):
    if var%2 :
        return ''
    else :
        return 'a'

if even(int(input("enter a number :"))) :
    print("no. is even")
else :
    print("no. is odd")
# Out:
# enter a number :3
# no. is odd

# %%
#prime,armstrong, month,week

num =int(input("enter value :"))
check =2
while num > check :
    if num % check == 0 :
        print("given no.{} is not prime no.".format(num))
        break
    check = check +1
else:
    print("given no.{} is prime".format(num))
# Out:
# enter value :5
# given no.5 is prime

# %%
def num(number) :
    check =2
    if number%check :
# Out:
#   File "<ipython-input-21-eae4a6463f0a>", line 3
#     if number%check :
#                      ^
# SyntaxError: unexpected EOF while parsing

# %%
def hello() :
    print("hello world")
    hello()

# %%
hello()  #---- recursion
# Out:
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# ...

# %%
s= 0
n=1
e= int(input("enter end point:"))
r = 0
if r<e :
    print("s:",s)
    fibnocci = s + n
    s = n
    n = fibnocci
    r = r+1
# Out:
# enter end point:100
# s: 0

# %%
#with third variable
x=5
y=7
z=x
x=y
y=z
print(x)
print(y)
# Out:
# 7
# 5

# %%
#without third variable

x= 5
y= 7
x,y=y,x
print(x)
print(y)
# Out:
# 7
# 5

# %%
#without third variable

x= 5
y = 7
x=x+y
y=x-y
x=x-y
print(x)
print(y)
# Out:
# 7
# 5

# %%
l=[[1,2,3],
   [4,5,6],
   [7,8,9]]

# %%
l[0]
# Out:
# [1, 2, 3]

# %%
matrix=[]
column=[]

# %%
m = int(input("no. of rows :"))
n=  int(input("no. of columns :"))
for row in range(m)
if m :
    print(m[index])
    print(n[index])
    index= index+1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-bef53a00cc7c> in <module>()
#       2 if m :
#       3     print()
# ----> 4     m=m.append[index]
#       5     n=n.append[index]
#       6     print(m)
#
# AttributeError: 'int' object has no attribute 'append'

# %%
m = int(input("enter no. of rows :"))
matirx=[
    list(map(int,input("enter row[{}] :".format(row).split()))) for row in range (m)
]
